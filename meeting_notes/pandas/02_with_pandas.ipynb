# %%
import pandas as pd

# %%
df = pd.read_csv('provinces.csv')
df
# Out:
#     Unnamed: 0                   Province Postalabbrev.        Capital  \
# 0          NaN                 Ontario[b]            ON        Toronto
# 1          NaN                     Quebec            QC    Quebec City
# 2          NaN                Nova Scotia            NS     Halifax[e]
# 3          NaN              New Brunswick            NB    Fredericton
# 4          NaN                   Manitoba            MB       Winnipeg
# 5          NaN           British Columbia            BC       Victoria
# 6          NaN       Prince Edward Island            PE  Charlottetown
# 7          NaN               Saskatchewan            SK         Regina
# 8          NaN                    Alberta            AB       Edmonton
# 9          NaN  Newfoundland and Labrador            NL     St. John's
# 10         NaN                      Total         Total          Total
#
#      Largest city Entered Confederation  Population  Land Area (km2)  \
# ...

# %%
df['Land Area (km2)']
# Out:
# 0      917741
# 1     1356128
# 2       53338
# 3       71450
# 4      553556
# 5      925186
# 6        5660
# 7      591670
# 8      642317
# 9      373872
# 10    5490918
# Name: Land Area (km2), dtype: int64

# %%
df['Land Area (km2)'].sum()
# Out:
# 10981836

# %% [markdown]
# # Output

# %%
df.to_csv('clean-provinces.csv')

# %%
df.to_excel('provinces.xlsx')
